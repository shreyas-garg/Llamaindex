# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyas-garg/Llamaindex/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install llama-index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.6/250.6 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.7/298.7 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 36.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import llama_index

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

# %%
import os
from getpass import getpass
from huggingface_hub import login

# %%
HF_TOKEN = getpass()
# Out:
# ··········

# %%
login(token=HF_TOKEN)

# %%
from llama_index.core.llama_dataset import download_llama_dataset

# %%
rag_dataset, documents = download_llama_dataset(
  "BlockchainSolanaDataset", "./solana"
)

# %%
rag_dataset.to_pandas()[:5]
# Out:
#                                                query  \
# 0  What are the key issues preventing the wide ad...
# 1  How does blockchain technology provide data se...
# 2  What is the projected growth rate of the block...
# 3  What are some of the challenges facing enterpr...
# 4  What are the key issues that need to be addres...
#
#                                   reference_contexts  \
# 0  [From Bitcoin to Solana – Innovating Blockchai...
# 1  [From Bitcoin to Solana – Innovating Blockchai...
# 2  [2 \n \nchain market size is expected to grow ...
# 3  [2 \n \nchain market size is expected to grow ...
# 4  [3 \n \nScalability.  Scalability  is the seco...
#
#                                     reference_answer reference_answer_by  \
# 0  The key issues preventing the wide adoption of...  ai (gpt-3.5-turbo)
# 1  Blockchain technology provides data security a...  ai (gpt-3.5-turbo)
# 2  The projected growth rate of the blockchain ma...  ai (gpt-3.5-turbo)
# ...

# %%
from llama_index.llms.huggingface import HuggingFaceInferenceAPI
llm = HuggingFaceInferenceAPI(model_name="mistralai/Mixtral-8x7B-Instruct-v0.1", token=HF_TOKEN)
# Out:
# <ipython-input-16-91d524a43560>:2: DeprecationWarning: Call to deprecated class HuggingFaceInferenceAPI. (Deprecated in favor of `HuggingFaceInferenceAPI` from `llama-index-llms-huggingface-api` which should be used instead.)
#   llm = HuggingFaceInferenceAPI(model_name="mistralai/Mixtral-8x7B-Instruct-v0.1", token=HF_TOKEN)

# %%
import tqdm
from llama_index.core.llama_pack import download_llama_pack

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# %%
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from llama_index.core import VectorStoreIndex
index = VectorStoreIndex.from_documents(documents=documents, embed_model=embed_model)

# %%
# evaluate using the RagEvaluatorPack
RagEvaluatorPack = download_llama_pack(
    "RagEvaluatorPack", "./rag_evaluator_pack"
)

# %%
query_engine = index.as_query_engine(llm=llm)

# %%
rag_evaluator_pack = RagEvaluatorPack(
    rag_dataset=rag_dataset, query_engine=query_engine, judge_llm=llm, embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
)

# %%
from llama_index.core.evaluation import FaithfulnessEvaluator
evaluator_model = FaithfulnessEvaluator(llm=llm)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
response_vector = query_engine.query("What is solana blockchain?")
eval_result = evaluator_model.evaluate_response(response=response_vector)

# %%
eval_result.response
# Out:
# "\nSolana is a blockchain platform that offers significant improvements in terms of scalability and performance compared to earlier platforms like Bitcoin and Ethereum. It achieves this by innovating on data structure, processes, and algorithms, consolidating various time-consuming algorithms and security enforcements, and differentiating and balancing users' responsibilities and rights while maintaining the required security and integrity inherent to blockchain systems. Solana has demonstrated 2-4 orders of magnitude of improvements, making it a promising platform for enterprise adoption."

# %%
response_vector = query_engine.query("teach a 5 year old boy what is erc20")
eval_result = evaluator_model.evaluate_response(response=response_vector)
eval_result.response
# Out:
# '\nERC20 is a special rule or a set of rules that people who create new tokens on the Ethereum blockchain have to follow. Think of it like a recipe for making a new toy car. Just like how there are many different types of toy cars, there are many different types of tokens that people can create on Ethereum. But, if they want other people to be able to use and trade their tokens, they have to make sure that their tokens follow the ERC20 rule. This way, everyone knows how to play with the new toy car, or how to use and trade the new token. It makes it easier for everyone to understand and use.'
